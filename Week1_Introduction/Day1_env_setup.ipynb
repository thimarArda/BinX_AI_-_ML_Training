# %% [markdown]
# Testing my first jupeter notebook as a part of the first day of BinX  AI & ML training program

# %%
import numpy as np
import pandas as pd
import matplotlib

print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Matplotlib:", matplotlib.__version__)
# Out:
# NumPy: 2.5.1
# Pandas: 3.0.3
# Matplotlib: 3.11.1
